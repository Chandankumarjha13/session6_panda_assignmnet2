# %% [markdown]
# #### Get Data from the following link: http://files.grouplens.org/datasets
# /movielens/ml-20m.zip
# #### We will be using the following files for this exercise:
# ratings.csv : userId,movieId,rating, timestamp
# tags.csv : userId,movieId, tag, timestamp
# movies.csv : movieId, title, genres

# %%
import pandas as pd

# %% [markdown]
# 1. Read the dataset using pandas.

# %%
# Soln
ratings = pd.read_csv("/home/chandan/Desktop/ASSIGNMENT/session6/ml-20m/ratings.csv") 
tags = pd.read_csv("/home/chandan/Desktop/ASSIGNMENT/session6/ml-20m/tags.csv") 
movies = pd.read_csv("/home/chandan/Desktop/ASSIGNMENT/session6/ml-20m/movies.csv")

# %% [markdown]
# 2. Extract the first row from tags and print its type.

# %%
tags.head(1)
# tags.head(1).info()
#
# Out:
#    userId  movieId          tag   timestamp
# 0      18     4141  Mark Waters  1240597180

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
# userId       465564 non-null int64
# movieId      465564 non-null int64
# tag          465548 non-null object
# timestamp    465564 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 14.2+ MB

# %% [markdown]
# Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
# userId       465564 non-null int64
# movieId      465564 non-null int64
# tag          465548 non-null object
# timestamp    465564 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 14.2+ MB

# %% [markdown]
# 3. Extract row 0, 11, 2000 from tags DataFrame.

# %%
tags.take([0,11,2000])
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %% [markdown]
# OUTPUT:
# 	userId	movieId	tag	timestamp
# 0	18	4141	Mark Waters	1240597180
# 11	65	1783	noir thriller	1368149983
# 2000	910	68554	conspiracy theory	1368043943

# %% [markdown]
# 4. Print index, columns of the DataFrame.

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %% [markdown]
# 5. Calculate descriptive statistics for the 'ratings' column of the
# ratings DataFrame. Verify using describe().

# %%
rating_df = ratings.rating
print('count',rating_df.count())
print('std',rating_df.std())
print('min',rating_df.min())
print('mean',rating_df.mean())
print('median',rating_df.median())
print('mode',rating_df.mode())
print('max',rating_df.max())
# Out:
# count 20000263
# std 1.051988919275684
# min 0.5
# mean 3.5255285642993797
# median 3.5
# mode 0    4.0
# dtype: float64
# max 5.0

# %%
rating_df.describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %% [markdown]
# 6. Filter out ratings with rating > 5

# %%
ratings[ratings.rating > 5]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %% [markdown]
# 7. Find how many null values, missing values are present. Deal
# with them. Print out how many rows have been modified.

# %%
# tags.isnull().values.ravel().sum()
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
tags=tags.fillna(" ")

# %% [markdown]
# #### 8. Filter out movies from the movies DataFrame that are of type
# 'Animation'.

# %%
# movies['Animation' in movies.genres]
movies["Indexes"]= movies["genres"].str.find('Animation')
movies[movies.Indexes > 0]['title'].head(5)
# Out:
# 0                                Toy Story (1995)
# 12                                   Balto (1995)
# 360                         Lion King, The (1994)
# 388    Secret Adventures of Tom Thumb, The (1993)
# 553                        Pagemaster, The (1994)
# Name: title, dtype: object

# %% [markdown]
# 9. Find the average rating of movies.

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %% [markdown]
# # 10. Perform an inner join of movies and tags based on movieId.

# %%
merge= pd.merge(movies,tags,how='inner',on='movieId')
merge.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    Indexes  userId                                     tag   timestamp
# 0       10    1644                                 Watched  1417736680
# 1       10    1741                      computer animation  1183903155
# 2       10    1741                 Disney animated feature  1183933307
# 3       10    1741                         Pixar animation  1183934770
# 4       10    1741  T̩a Leoni does not star in this movie  1245093573

# %% [markdown]
# # 11. Print out the 5 movies that belong to the Comedy genre and
# have rating greater than 4.

# %%
movie_ratings= pd.merge(ratings,movies,how='inner',on='movieId')
movie_ratings.head(10)
# movie_ratings.loc[(movie_ratings["genres"].str.find('Comedy')) & (movie_ratings["rating"] > 4), "title"].head(5)
# query('genres > 50 and C != 900')

# %%
# Out:
# 1     Toy Story (1995)
# 4     Toy Story (1995)
# 7     Toy Story (1995)
# 9     Toy Story (1995)
# 14    Toy Story (1995)
# Name: title, dtype: object

# %% [markdown]
# # 12. Split 'genres' into multiple columns.

# %%
genres_split = movies['genres'].str.split("|", expand = False)
genres_split.head(5)
# movies['genres_split'].head(5)
# Out:
# 0    [Adventure, Animation, Children, Comedy, Fantasy]
# 1                       [Adventure, Children, Fantasy]
# 2                                    [Comedy, Romance]
# 3                             [Comedy, Drama, Romance]
# 4                                             [Comedy]
# Name: genres, dtype: object

# %% [markdown]
# # 13. Extract year from title e.g. (1995).

# %%
# movies['a'],movies['b'] = movies['title'].str.split('(', 1).str
# movies['title'].str.split(' ')
new = movies['title'].str.split(" ", expand = True)
new
# Out:
#                0            1            2          3        4       5   \
# 0             Toy        Story       (1995)       None     None    None
# 1         Jumanji       (1995)         None       None     None    None
# 2        Grumpier          Old          Men     (1995)     None    None
# 3         Waiting           to       Exhale     (1995)     None    None
# 4          Father           of          the      Bride     Part      II
# 5            Heat       (1995)         None       None     None    None
# 6         Sabrina       (1995)         None       None     None    None
# 7             Tom          and         Huck     (1995)     None    None
# 8          Sudden        Death       (1995)       None     None    None
# 9       GoldenEye       (1995)         None       None     None    None
# 10       American   President,          The     (1995)     None    None
# 11       Dracula:         Dead          and     Loving       It  (1995)
# ...
